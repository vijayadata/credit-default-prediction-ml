# %%
import kaggle
# !kaggle datasets credit-default -f credit default.csv
# Out:
# usage: kaggle datasets [-h]
#                        {list,files,download,create,version,init,metadata,status}
#                        ...
# kaggle datasets: error: argument command: invalid choice: 'credit-default' (choose from 'list', 'files', 'download', 'create', 'version', 'init', 'metadata', 'status')

# %%
import os
import zipfile
zip_path = r"C:\Users\siva9\Downloads\archive.zip"   # path to your zip file
extract_path = r"C:\Users\siva9\Downloads\archive_unzipped"
os.makedirs(extract_path, exist_ok=True) 

with zipfile.ZipFile(zip_path,'r') as zip_ref:
 zip_ref.extractall(extract_path)
print("Files Extracted to",extract_path)
print("files extacted",os.listdir(extract_path))
# Out:
# Files Extracted to C:\Users\siva9\Downloads\archive_unzipped
# files extacted ['credit_default.csv']

# %%
import zipfile
import os

# Path to your zip file in Downloads
zip_path = r"C:\Users\siva9\Downloads\archive.zip"

# Folder where you want to extract files
extract_path = r"C:\Users\siva9\Downloads\archive_unzipped"

# Create the folder if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Open and extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Show the files extracted
print("Files Extracted to:", extract_path)
print("Files extracted:", os.listdir(extract_path))
# Out:
# Files Extracted to: C:\Users\siva9\Downloads\archive_unzipped
# Files extracted: ['credit_default.csv']

# %%
os.listdir(extract_path)
# Out:
# ['credit_default.csv']

# %%
import pandas as pd
df=pd.read_csv('C:/Users/siva9/Downloads/archive_unzipped/credit_default.csv')

# %%
df.head(5)
# Out:
#     Loan_ID  Gender  Married  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  LP001003     1.0      1.0           4583.0             1508.0         128
# 1  LP001005     1.0      1.0           3000.0                0.0          66
# 2  LP001006     1.0      1.0           2583.0             2358.0         120
# 3  LP001008     1.0      0.0           6000.0                0.0         141
# 4  LP001011     1.0      1.0           5417.0             4196.0         267
#
#    Loan_Status
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            529 non-null    object
#  1   Gender             515 non-null    float64
#  2   Married            525 non-null    float64
#  3   ApplicantIncome    527 non-null    float64
#  4   CoapplicantIncome  529 non-null    float64
#  5   LoanAmount         529 non-null    int64
#  6   Loan_Status        529 non-null    int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 29.1+ KB

# %%
df.describe()
# Out:
#            Gender     Married  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  515.000000  525.000000       527.000000         529.000000  529.000000
# mean     0.817476    0.643810      5497.100569        1542.394934  145.852552
# std      0.386652    0.479329      6408.772743        2524.295797   84.108409
# min      0.000000    0.000000       150.000000           0.000000    9.000000
# 25%      1.000000    0.000000      2897.500000           0.000000  100.000000
# 50%      1.000000    1.000000      3814.000000        1086.000000  128.000000
# 75%      1.000000    1.000000      5807.500000        2232.000000  167.000000
# max      1.000000    1.000000     81000.000000       33837.000000  700.000000
#
#        Loan_Status
# count   529.000000
# mean      0.691871
# std       0.462157
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'ApplicantIncome', 'CoapplicantIncome',
#        'LoanAmount', 'Loan_Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (529, 7)

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender               float64
# Married              float64
# ApplicantIncome      float64
# CoapplicantIncome    float64
# LoanAmount             int64
# Loan_Status            int64
# dtype: object

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 8.1/8.1 MB 20.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 225.2/225.2 kB 13.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.3/2.3 MB 24.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.8/73.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 7.0/7.0 MB 26.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 113.9/113.9 kB 6.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# !pip install seaborn
import seaborn as sns
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 294.9/294.9 kB 4.5 MB/s eta 0:00:00
# ...

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
# Out:
# ...
#      ---------------------------------------- 8.9/8.9 MB 18.3 MB/s eta 0:00:00
# ...
#      --------------------------------------- 38.7/38.7 MB 15.2 MB/s eta 0:00:00
# ...
#      ------------------------------------- 308.4/308.4 kB 19.9 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# !pip install joblib
import joblib
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df=pd.read_csv('C:/Users/siva9/Downloads/archive_unzipped/credit_default.csv')

# %%
print("dataset shape:",df.shape)
print(df.head())
# Out:
# dataset shape: (529, 7)
#     Loan_ID  Gender  Married  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  LP001003     1.0      1.0           4583.0             1508.0         128
# 1  LP001005     1.0      1.0           3000.0                0.0          66
# 2  LP001006     1.0      1.0           2583.0             2358.0         120
# 3  LP001008     1.0      0.0           6000.0                0.0         141
# 4  LP001011     1.0      1.0           5417.0             4196.0         267
#
#    Loan_Status
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            529 non-null    object
#  1   Gender             515 non-null    float64
#  2   Married            525 non-null    float64
#  3   ApplicantIncome    527 non-null    float64
#  4   CoapplicantIncome  529 non-null    float64
#  5   LoanAmount         529 non-null    int64
#  6   Loan_Status        529 non-null    int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 29.1+ KB
# None
# Loan_ID               0
# Gender               14
# Married               4
# ApplicantIncome       2
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Status           0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=df, x="Gender")
plt.title("Default Distribution(0= No,1= Yes)")
plt.show()

# %%
import matplotlib.pyplot as plt
gender_counts=df["Gender"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=["skyblue","lightpink"]
)
plt.title("Gender Distribution")
plt.show()

# %%
if L
scalar=StandardScaler()
X_scaled=scalar.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40300\79700577.py in ?()
#       1 scalar=StandardScaler()
# ----> 2 X_scaled=scalar.fit_transform(X)
#
# c:\Users\siva9\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# c:\Users\siva9\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     890                 )
#     891
#     892         if y is None:
# ...

# %%
plt.show()

# %%
if "Loan_ID" in df.columns:
    df.drop("Loan_ID",axis=1,inplace=True)

# %%
X=df.drop("Gender",axis=1)
y=df["Gender"]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
if "Loan_Id" in df.columns:
    df.drop("Loan_Id",axis=1,inplace=True)

    X=df.drop("Gender",axis=1)
    y=df["Gender"]
X= pd.get_dummies(X,drop_first=True)
scalar=StandardScaler()
X_scaled=scalar.fit_transform(X)
# print("X_scaled shape:", X X_scaled.shape)
# print("y shape:",y.shape)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             515 non-null    float64
#  1   Married            525 non-null    float64
#  2   ApplicantIncome    527 non-null    float64
#  3   CoapplicantIncome  529 non-null    float64
#  4   LoanAmount         529 non-null    int64
#  5   Loan_Status        529 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 24.9 KB

# %%
df.head(5)
# Out:
#    Gender  Married  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0     1.0      1.0           4583.0             1508.0         128
# 1     1.0      1.0           3000.0                0.0          66
# 2     1.0      1.0           2583.0             2358.0         120
# 3     1.0      0.0           6000.0                0.0         141
# 4     1.0      1.0           5417.0             4196.0         267
#
#    Loan_Status
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df.describe()
# Out:
#            Gender     Married  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  515.000000  525.000000       527.000000         529.000000  529.000000
# mean     0.817476    0.643810      5497.100569        1542.394934  145.852552
# std      0.386652    0.479329      6408.772743        2524.295797   84.108409
# min      0.000000    0.000000       150.000000           0.000000    9.000000
# 25%      1.000000    0.000000      2897.500000           0.000000  100.000000
# 50%      1.000000    1.000000      3814.000000        1086.000000  128.000000
# 75%      1.000000    1.000000      5807.500000        2232.000000  167.000000
# max      1.000000    1.000000     81000.000000       33837.000000  700.000000
#
#        Loan_Status
# count   529.000000
# mean      0.691871
# std       0.462157
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y , test_size=0.3, random_state=42
    )
print(y.value_counts())
# Out:
# Gender
# 1.0    421
# 0.0     94
# Name: count, dtype: int64

# %%
log_reg= LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 2
#       1 log_reg= LogisticRegression(max_iter=1000)
# ----> 2 log_reg.fit(X_train, y_train)
#
# File c:\Users\siva9\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\siva9\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1247, in LogisticRegression.fit(self, X, y, sample_weight)
#    1244 else:
#    1245     _dtype = [np.float64, np.float32]
# ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (370, 533)
# (370,)

# %%
y_train=y_train.ravel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 y_train=y_train.ravel()
#
# AttributeError: 'function' object has no attribute 'ravel'

# %%
from sklearn.preprocessing import LabelEncoder
y_train =LabelEncoder().fit_transform(y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 from sklearn.preprocessing import LabelEncoder
# ----> 2 y_train =LabelEncoder().fit_transform(y_train)
#
# File c:\Users\siva9\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:110, in LabelEncoder.fit_transform(self, y)
#      97 def fit_transform(self, y):
#      98     """Fit label encoder and return encoded labels.
#      99
#     100     Parameters
#    (...)    108         Encoded labels.
#     109     """
# --> 110     y = column_or_1d(y, warn=True)
#     111     self.classes_, y = _unique(y, return_inverse=True)
#     112     return y
#
# File c:\Users\siva9\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1483, in column_or_1d(y, dtype, warn, device)
#    1470         warnings.warn(
#    1471             (
# ...
